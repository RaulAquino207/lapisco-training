# %% [markdown]
# ### Trainner - LAPISCO - 2020
# #### Professor: Aldísio Medeiros

# %% [markdown]
# ##### Questão 1 - Explique a diferença entre Shell x Bash x Terminal. Nota: Explique o que você entendeu com base na leitura de materiais sugeridos e em aula.
#
# R: Entendemos como o *Shell* a "interface" entre o kernel e o usuário, uma camada que disponibiliza uma linguagem programável entre os mesmos, ele funciona como o interpretador, como também a própria linguagem. Existem vários tipos de *Shell*, e um dos tipos se chama *Bash* e por fim temos o *terminal* que é por onde escrevemos nossas linhas de comandos, ele é um programa que recebe os comandos do usuário a partir do teclado e repassa-os às camadas de baixo nível do sistema operacional.

# %% [markdown]
# ##### Questão 2 - Há um arquivo de logs que diariamente está sendo alimentado, utilizando o comando sed, escreva um comando ou combinação de comandos com base neste, para listar o arquivo de log, exceto a última e penúltima linha. Nota: Considere um arquivo de log com a estrutura abaixo: ![image.png](attachment:image.png) Após executar o comando devem ser retornas apenas as linhas ![image-2.png](attachment:image-2.png) Este comportamento deve se repetir mesmo após o arquivo ser novamente alimentado pelo log, isto é, os índices das linhas removidas não podem ser fixos.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##### Questão 3 - Apresente um comando ou sequência de comandos que leia o arquivo nomes.txt que armazena o conteúdo apresentado na Tabela 1, e liste os nome (apenas os nomes) na ordem crescente pelo número de caracteres. ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Questão 4 - Apresente um comando ou sequência de comandos que imprima na tela as seguintes informações: Número de processado- res disponíveis na máquina, o nome do modelo dos processadores, o total de memória RAM consumida, o total de memória livre e o total de SWAP utilizada. Nota1 : Esses dados podem ser obtidos no diretório /proc. Nota2 : Você poderá usar arquivos temporários, caso precise. Seu(s) comando(s) deve(em) listar os dados a cada 1 segundo. Um exemplo da saída esperada com os respectivos cam- pos:
#
# - NumCores: 12
# - ModelName: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# - MemTotal: 16249692 kB
# - MemFree: 7287532 kB
# - SwapUsed: 7148 kB

# %% [markdown]
# watch -n 1 'echo "NumCores:"; grep "model name" /proc/cpuinfo | wc -l;
# cat /proc/cpuinfo | grep "model name" | uniq;
# cat /proc/meminfo | grep "Mem*" | sed "$ d";
# cat /proc/meminfo | grep "SwapCached"'
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Questão 5 - Liste os diretórios e arquivos presentes dentro do diretório home do usuário logado cujo dono é diferente do usuário logado. Por exemplo, se estou logado com o usuário joao e dentro do diretório /home/joao tem dois aquivos cujo dono é o root e um terceiro arquivo cujo dono é o usuário maria, seu comando ou sequência de comandos deve listar: três aqruivos com as permissões de usuário, grupo do usuário e outros, nome do aquivo e tamanho em bytes.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Questão 6 - Utilizando apenas comandos, faça o download da base 2 IRIS disponível no repositório UCI (arquivo iris.data). Após o download, separe as linhas em três diferentes arquivos: setosa.txt, virginica.txt e versicolor.txt. Cada um destes arquivos deve conter suas respectivas linhas ordenadas pelo comprimento da sépala de forma crescente (observe a legenda das colunas do arquivo iris.data). Nota1: Para fazer o download veja o comando wget.Nota2: Arquivo disponível no link: https://archive.ics.uci.edu/ml/machine-learning-databases/iris/

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#!wget "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data" -O iris.csv

# %%
import pandas as pd
df = pd.read_csv('iris.csv', header=None)
df
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Questão 7 - Ainda utilizando o arquivo iris.data, apresente o comprimento médio da pétala para cada uma das três classes utilizando somente comandos linux.

# %%
# !awk '{ total += $1; count++ } END { print total/count }' setosa.txt
# !awk '{ total += $1; count++ } END { print total/count }' setosa.txt
# !awk '{ total += $1; count++ } END { print total/count }' setosa.txt

# %% [markdown]
# ![image.png](attachment:image.png)
